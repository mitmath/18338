# %%
using RandomMatrices, SpecialPolynomials

# %%
?RandomMatrices
# Out:
# search: RandomMatrices
#   No docstring found for module RandomMatrices.
#
#   Exported names
#   ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡
#
#   AiryProcess, BrownianProcess, FormalLaurentSeries, FormalPowerSeries,
#   GaussianHermite, GaussianJacobi, GaussianLaguerre, Ginibre, Haar, MANOVA,
#   MatrixForm, Semicircle, Stewart, TracyWidom, WeingartenUnitary,
#   WhiteNoiseProcess, Wigner, Wishart, bidrand, cdf, cf, compose, cumulant,
#   cycle_structure, data, derivative, eigvaljpdf, eigvalrand, entropy,
#   expectation, fps, freecumulant, hist_eig, insupport, isalmostunit,
#   isconstant, isnonunit, isunit, kurtosis, mean, median, mgf, modes, moment,
#   next!, part, partition, pdf, permutations_in_Sn, rand, randfast, reciprocal,
#   skewness, sprand, std, tovector, tridrand, trim, var
#
#   Displaying contents of readme found at
#  C:\Users\Harry\.julia\packages\RandomMatrices\6EU7I\README.md
#   ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡
#
#   RandomMatrices.jl
# ...
