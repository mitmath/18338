# %%
using LinearAlgebra

# %%
using Plots
# Out:
# ┌ Info: Recompiling stale cache file /Users/edelman/.julia/compiled/v1.2/Plots/ld3vC.ji for Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1240

# %%
sym(A)=A+A'
n=20; s=500; h=(0:s)/s
G=[sym(randn(n,n)) for i=h]/√s
G[1]*=0; G=cumsum(G)
#G-=[G[end]*i for i=h]
e=map(eigvals,G)
plot()
for j=1:n  plot!(h,[e[i][j] for i=1:s+1])  end

# %%
plot!(legend=false)
