# %%
using LinearAlgebra

# %%
using Plots

# %%
sym(A)=A+A'
n=20; s=500; h=(0:5*s)/s
G=[sym(randn(n,n)) for i=h]/√s
G[1]*=0; G=cumsum(G)
#G-=[G[end]*i for i=h]
e=map(eigvals,G)
plot()
for j=1:n  plot!(h,[e[i][j]/sqrt(i*s) for i=1:5*s+1])  end

# %%
plot!(legend=false)   # P(purple curve (probably normalized) at time s1 < λ1 ) and at time s2 <λ2 is the extended airy process
