# %% [markdown]
# A Projection Process

# %%
using LinearAlgebra, Combinatorics

# %%
n,p = 8,5
Y,_ = qr(randn(n,p))
Y = Matrix(Y)
K = Y*Y'
# Out:
# 8×8 Array{Float64,2}:
#   0.519395   -0.0266454  -0.121366   …  -0.122569    0.165816    0.109497
#  -0.0266454   0.925651   -0.18396        0.119937   -0.111599    0.030498
#  -0.121366   -0.18396     0.472268       0.151384   -0.344574   -0.09811
#   0.311876   -0.0112848   0.0616565      0.229121   -0.0814426   0.0854452
#  -0.28707    -0.0798321  -0.213505       0.0654737   0.0133582   0.127318
#  -0.122569    0.119937    0.151384   …   0.508355    0.0757071  -0.367546
#   0.165816   -0.111599   -0.344574       0.0757071   0.61253    -0.257125
#   0.109497    0.030498   -0.09811       -0.367546   -0.257125    0.447654

# %%
# All combinations of p subsets of 1:n
[𝓘 for 𝓘 ∈ combinations(1:n,p)]
# Out:
# 56-element Array{Array{Int64,1},1}:
#  [1, 2, 3, 4, 5]
#  [1, 2, 3, 4, 6]
#  [1, 2, 3, 4, 7]
#  [1, 2, 3, 4, 8]
#  [1, 2, 3, 5, 6]
#  [1, 2, 3, 5, 7]
#  [1, 2, 3, 5, 8]
#  [1, 2, 3, 6, 7]
#  [1, 2, 3, 6, 8]
#  [1, 2, 3, 7, 8]
#  [1, 2, 4, 5, 6]
#  [1, 2, 4, 5, 7]
#  [1, 2, 4, 5, 8]
#  ⋮
#  [2, 3, 6, 7, 8]
#  [2, 4, 5, 6, 7]
#  [2, 4, 5, 6, 8]
#  [2, 4, 5, 7, 8]
#  [2, 4, 6, 7, 8]
#  [2, 5, 6, 7, 8]
#  [3, 4, 5, 6, 7]
#  [3, 4, 5, 6, 8]
#  [3, 4, 5, 7, 8]
#  [3, 4, 6, 7, 8]
#  [3, 5, 6, 7, 8]
#  [4, 5, 6, 7, 8]

# %% [markdown]
# ## This is a probability space
#
# specifically P(𝓘) = det(K[𝓘,𝓘]) is thought of as the probability of 𝓘

# %%
sum(det(K[𝓘,𝓘]) for 𝓘 ∈ combinations(1:n,p) )
# Out:
# 0.9999999999999992

# %% [markdown]
# ## if you take sizes j smaller than p you need to correct with binomial(p,j)

# %%
[[sum(det(K[𝒬,𝒬]) for 𝒬 ∈ combinations(1:n,j) ) for j=0:p] [binomial(p,j) for j=0:p]]
# Out:
# 6×2 Array{Float64,2}:
#   1.0   1.0
#   5.0   5.0
#  10.0  10.0
#  10.0  10.0
#   5.0   5.0
#   1.0   1.0

# %% [markdown]
# ## a really nice property of projection processes

# %%
## associate 𝓘  with its probability
## then associate all j subsets of 𝓘 with that probability over binomial(p,j)
## now add up the probabilities for all j subsets ... that will be the j subset probabilty

# %%
d = Dict{Array{Int64,1},Float64}()
 for 𝓘 ∈ combinations(1:n, p)
    prob = det(K[𝓘,𝓘])/binomial(n,p)
    for 𝒬 ∈ combinations(𝓘,j)
        if haskey(d,𝒬)
            d[𝒬] += prob
        else
            d[𝒬] = prob
        end
    end
end

# %%
# the answer that I expect is
for 𝒬 ∈ combinations(1:n, j)    
      println(𝒬," ",det(K[𝒬,𝒬]) / binomial(n,j)," ", d[𝒬]  ) 
end
# Out:
# [1, 2, 3] 0.0034699880718057872 0.003469988071805788
# [1, 2, 4] 0.004779611915686593 0.004779611915686594
# [1, 2, 5] 0.005151928269090404 0.005151928269090406
# [1, 2, 6] 0.003990198210764709 0.003990198210764712
# [1, 2, 7] 0.004698626855055503 0.004698626855055505
# [1, 2, 8] 0.0036275986289770424 0.0036275986289770455
# [1, 3, 4] 0.0021277468554745187 0.0021277468554745187
# [1, 3, 5] 0.0017839652672990553 0.0017839652672990557
# [1, 3, 6] 0.0018341796324807056 0.001834179632480706
# [1, 3, 7] 0.0014364724837640315 0.0014364724837640326
# [1, 3, 8] 0.0016992606889317831 0.001699260688931784
# [1, 4, 5] 0.0021953840619569702 0.0021953840619569707
# [1, 4, 6] 0.0016293752831319866 0.0016293752831319868
# [1, 4, 7] 0.0025899820011548646 0.0025899820011548638
# [1, 4, 8] 0.0021920144503909853 0.002192014450390986
# [1, 5, 6] 0.002715299458980043 0.0027152994589800437
# [1, 5, 7] 0.003067098371429574 0.0030670983714295736
# [1, 5, 8] 0.002077389908489504 0.0020773899084895048
# [1, 6, 7] 0.002366018224881975 0.0023660182248819747
# [1, 6, 8] 0.0008049583481985477 0.000804958348198548
# [1, 7, 8] 0.001412336583001841 0.0014123365830018423
# [2, 3, 4] 0.0053049913832794605 0.005304991383279462
# [2, 3, 5] 0.004621384620918706 0.004621384620918709
# [2, 3, 6] 0.0030417833659013164 0.003041783365901318
# [2, 3, 7] 0.0020912217918051834 0.0020912217918051855
# [2, 3, 8] 0.0030767304910278696 0.003076730491027872
# [2, 4, 5] 0.009019113172131766 0.009019113172131768
# [2, 4, 6] 0.005187451727047597 0.005187451727047599
# [2, 4, 7] 0.007260976373409765 0.0072609763734097655
# [2, 4, 8] 0.005376291184435794 0.005376291184435798
# [2, 5, 6] 0.006115689765010978 0.006115689765010983
# [2, 5, 7] 0.007549622803333681 0.007549622803333683
# [2, 5, 8] 0.005349775343408954 0.005349775343408959
# [2, 6, 7] 0.00474567400102006 0.004745674001020063
# [2, 6, 8] 0.0013571532753785737 0.0013571532753785761
# [2, 7, 8] 0.0033611180291190585 0.0033611180291190624
# [3, 4, 5] 0.003914298999539483 0.003914298999539483
# [3, 4, 6] 0.002487550044924938 0.0024875500449249386
# [3, 4, 7] 0.0022326582924556233 0.0022326582924556237
# [3, 4, 8] 0.002573477256009573 0.002573477256009574
# [3, 5, 6] 0.002457777336785348 0.002457777336785349
# [3, 5, 7] 0.001877908933919842 0.0018779089339198433
# [3, 5, 8] 0.00236623746679041 0.0023662374667904116
# [3, 6, 7] 0.001108141459076915 0.0011081414590769158
# [3, 6, 8] 0.0007042793778299085 0.0007042793778299094
# [3, 7, 8] 0.0003900355377789372 0.00039003553777893884
# [4, 5, 6] 0.004300089451561283 0.004300089451561283
# [4, 5, 7] 0.005922956533828892 0.00592295653382889
# [4, 5, 8] 0.004143532421994805 0.0041435324219948055
# [4, 6, 7] 0.003380488431764528 0.0033804884317645283
# [4, 6, 8] 0.0004871011451727729 0.0004871011451727745
# [4, 7, 8] 0.002698732257539514 0.002698732257539515
# [5, 6, 7] 0.004152801810671407 0.004152801810671409
# [5, 6, 8] 0.0009795815604604888 0.0009795815604604905
# [5, 7, 8] 0.002664303615166353 0.0026643036151663556
# [6, 7, 8] 0.0006210657399823996 0.0006210657399824012
